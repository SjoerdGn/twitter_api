# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import json
from pprint import *

# %%
plt.figure(figsize=(15, 15))
m = Basemap(resolution=None, lat_0=0, lon_0=-0)
m.bluemarble(scale=1);


file = "output/tweets.json"

tweets = []

for line in open(file, 'r'):
    tweets.append(json.loads(line))

coor = []

correct_cor = 0
for i in range(len(tweets)):
    all_coor = tweets[i]['coordinates']
    print(all_coor)
    if all_coor:
        correct_coor += 1
        exact_coor = all_coor['coordinates']
        m.scatter(exact_coor[0],exact_coor[1],3,marker='o',color='y')
        coor.append(exact_coor)

plt.savefig('output/map_pils_zuipen_beer_drinks', dpi = 150)
print("There were {correct} correct out of {total} total tweets.".format(correct = correct_coor, total = len(tweets)))
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# {'type': 'Point', 'coordinates': [-70.3696, 43.6765]}
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# {'type': 'Point', 'coordinates': [-75.3451, 40.1083]}
# None
# {'type': 'Point', 'coordinates': [-80.1404, 25.789]}
# None
# None
# None
# None
# {'type': 'Point', 'coordinates': [-83.7683, 34.4048]}
# {'type': 'Point', 'coordinates': [-38.5073, -3.74572]}
# {'type': 'Point', 'coordinates': [-85.6729, 42.9635]}
# None
# None
# {'type': 'Point', 'coordinates': [-89.326, 43.048]}
# None
# None
# None
# {'type': 'Point', 'coordinates': [-77.029, -12.1216]}
# None
# None
# None
# {'type': 'Point', 'coordinates': [-96.8638, 33.0784]}
# None
# {'type': 'Point', 'coordinates': [6.39529, 51.8957]}
# None
# None
# None
# None
# None
# None
# None
# None
# {'type': 'Point', 'coordinates': [-92.4637, 44.7346]}
# {'type': 'Point', 'coordinates': [-96.0757, 41.1721]}
# None
# {'type': 'Point', 'coordinates': [-80.2417, 36.1]}
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# {'type': 'Point', 'coordinates': [-117.127, 32.7483]}
# None
# None
# None
