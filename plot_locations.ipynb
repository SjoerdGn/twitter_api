# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import json
from pprint import *

# %%
plt.figure(figsize=(15, 15))
m = Basemap(resolution=None, lat_0=0, lon_0=-0)
m.bluemarble(scale=1);


file = "output/tweets.json"

tweets = []

for line in open(file, 'r'):
    tweets.append(json.loads(line))

coor = []

correct_coor = 0
for i in range(len(tweets)):
    all_coor = tweets[i]['coordinates']
    if all_coor:
        correct_coor += 1
        exact_coor = all_coor['coordinates']
        m.scatter(exact_coor[0],exact_coor[1],3,marker='o',color='y')
        coor.append(exact_coor)

plt.savefig('output/map_pils_zuipen_beer_drinks', dpi = 150)
print("There were {correct} with a location out of {total} total tweets.".format(correct = correct_coor, total = len(tweets)))
# Out:
# There were 56 with a location out of 6211 total tweets.
